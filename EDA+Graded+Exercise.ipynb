# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("Attribute+DataSet.csv")
#
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
inp0["Size"]=inp0["Size"].str.lower()

# %%
size_mapping={'m':'Medium','l':'Large','xl':'Extra Large','free':'Free','s':'Small'}
inp0['Size']=inp0['Size'].map(size_mapping)
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
# Print the value counts of each category in "Size" column.
inp0["Size"].value_counts(normalize=True)
# Out:
# Medium         0.357741
# Free           0.345188
# Large          0.194561
# Small          0.073222
# Extra Large    0.029289
# Name: Size, dtype: float64

# %%
inp1= pd.read_csv("Dress+Sales.csv")
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 0        2887        2930       3119       3204  ...       3554     3624.0
# 1        1066        1164       1558       1756  ...       2710     2942.0
# 2           8           9         10         10  ...         11       11.0
# 3        1621        1637       1723       1746  ...       1878     1892.0
# 4        1559        1570       1638       1655  ...       2032     2156.0
#
# ...

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
inp1["14-09-2013"]=inp1["14-09-2013"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 inp1["14-09-2013"]=inp1["14-09-2013"].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.loc[inp1['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
inp1['09-12-2013']=inp1['09-12-2013'].astype(float)

# %%
inp1.loc[inp1['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

inp1.loc[inp1['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

inp1.loc[inp1['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

inp1.loc[inp1['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

inp1.loc[inp1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
inp1["14-09-2013"]=inp1["14-09-2013"].astype(float)
inp1["16-09-2013"]=inp1["16-09-2013"].astype(float)
inp1["18-09-2013"]=inp1["18-09-2013"].astype(float)
inp1["20-09-2013"]=inp1["20-09-2013"].astype(float)
inp1["22-09-2013"]=inp1["22-09-2013"].astype(float)

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
inp1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      1
# 14-09-2013      1
# 16-09-2013      1
# 18-09-2013      1
# 20-09-2013      1
# 22-09-2013      1
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1.shape
# Out:
# (479, 24)

# %%
inp1.describe()
# Out:
#            Dress_ID   29-08-2013   31-08-2013   09-02-2013   09-04-2013  \
# count  4.790000e+02   479.000000   479.000000   479.000000   479.000000
# mean   9.022420e+08   198.085595   209.776618   223.551148   299.791232
# std    1.822352e+08   579.189322   590.836166   603.098222   601.716515
# min    1.234568e+08     0.000000     0.000000     0.000000     1.000000
# 25%    7.666611e+08     0.000000     0.000000     0.000000    28.500000
# 50%    9.096250e+08     2.000000     3.000000     4.000000   110.000000
# 75%    1.039684e+09   138.500000   165.500000   194.500000   308.500000
# max    1.253973e+09  7455.000000  7467.000000  7479.000000  7374.000000
#
#         09-06-2013   09-08-2013   09-10-2013   09-12-2013   14-09-2013  ...  \
# count   479.000000   479.000000   479.000000   478.000000   478.000000  ...
# mean    304.745303   316.534447   320.100209   334.085774   340.569038  ...
# std     603.854257   609.070537   610.360681   618.276697   623.329861  ...
# ...

# %%
float(100.00*259/479)
# Out:
# 54.07098121085595

# %%
float(100.00*257/479)
# Out:
# 53.65344467640919

# %%
float(100.00*258/479)
# Out:
# 53.86221294363257

# %%
float(100.00*255/479)
# Out:
# 53.23590814196242

# %%
float(100.00*222/479)
# Out:
# 46.34655532359081

# %%
inp1= inp1.drop(["26-09-2013"] , axis= 1)

inp1= inp1.drop(["30-09-2013"] , axis= 1)

inp1= inp1.drop(["10-02-2013"] , axis= 1)

inp1= inp1.drop(["10-04-2013"] , axis= 1)

inp1= inp1.drop(["10-08-2013"] , axis= 1)

inp1= inp1.drop(["10-10-2013"] , axis= 1)

# %%
inp1.shape
# Out:
# (479, 18)

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
inp1.iloc[:0,1:]
# Out:
# Empty DataFrame
# Columns: [29-08-2013, 31-08-2013, 09-02-2013, 09-04-2013, 09-06-2013, 09-08-2013, 09-10-2013, 09-12-2013, 14-09-2013, 16-09-2013, 18-09-2013, 20-09-2013, 22-09-2013, 24-09-2013, 28-09-2013, 10-06-2013, 10-12-2013]
# Index: []

# %%
# Create the four seasons columns in inp1, according to the above criteria.

inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
inp1['Spring'] = inp1['09-04-2013']
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
inp1['Winter'] = inp1['09-12-2013'] + inp1['10-12-2013'] + inp1['09-02-2013']

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  28-09-2013  479 non-null    int64
#  16  10-06-2013  479 non-null    int64
#  17  10-12-2013  479 non-null    int64
#  18  Spring      479 non-null    int64
# ...

# %%
inp1["Summer"]=inp1["10-06-2013"]+inp1["09-08-2013"]+inp1["09-06-2013"]+inp1["31-08-2013"]+inp1["29-08-2013"]

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  18-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3321.0
# 1        1066        1164      1558.0      1756.0  ...      1985.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1796.0
# 4        1559        1570      1638.0      1655.0  ...      1743.0
#
#    20-09-2013  22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  \
# ...

# %%
inp1["Autumn"]=inp1["09-10-2013"]+inp1["14-09-2013"]+inp1["16-09-2013"]+inp1["18-09-2013"]+inp1["20-09-2013"]+inp1["22-09-2013"]+inp1["24-09-2013"] +inp1["28-09-2013"]

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  20-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3386.0
# 1        1066        1164      1558.0      1756.0  ...      2106.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1812.0
# 4        1559        1570      1638.0      1655.0  ...      1824.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Winter  \
# ...

# %%
inp1["Winter"].sum()
# Out:
# 473640.0

# %%
inp1["Summer"].sum()
# Out:
# 691907

# %%
inp1["Autumn"].sum()
# Out:
# 1353543.0

# %%
inp1["Spring"].sum()
# Out:
# 143600

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Spring  Winter  Summer   Autumn
# ...

# %%
inp0.describe()
# Out:
#            Dress_ID      Rating  Recommendation   29-08-2013   31-08-2013  \
# count  4.790000e+02  479.000000      479.000000   479.000000   479.000000
# mean   9.022420e+08    3.489353        0.427975   198.085595   209.776618
# std    1.822352e+08    2.028941        0.495302   579.189322   590.836166
# min    1.234568e+08    0.000000        0.000000     0.000000     0.000000
# 25%    7.666611e+08    2.000000        0.000000     0.000000     0.000000
# 50%    9.096250e+08    4.600000        0.000000     2.000000     3.000000
# 75%    1.039684e+09    4.800000        1.000000   138.500000   165.500000
# max    1.253973e+09    5.000000        1.000000  7455.000000  7467.000000
#
#         09-02-2013   09-04-2013   09-06-2013   09-08-2013   09-10-2013  ...  \
# count   479.000000   479.000000   479.000000   479.000000   479.000000  ...
# mean    223.551148   299.791232   304.745303   316.534447   320.100209  ...
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
#inp0.drop(inp0.loc[:,'29-08-2013_y':'10-12-2013_y'].columns, axis= 1, inplace= True)
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                1
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# 29-08-2013          0
# 31-08-2013          0
# 09-02-2013          0
# 09-04-2013          0
# 09-06-2013          0
# 09-08-2013          0
# 09-10-2013          0
# 09-12-2013          1
# 14-09-2013          1
# 16-09-2013          1
# 18-09-2013          1
# 20-09-2013          1
# 22-09-2013          1
# 24-09-2013          0
# 28-09-2013          0
# 10-06-2013          0
# 10-12-2013          0
# Spring              0
# Winter              1
# Summer              0
# Autumn              2
# dtype: int64

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                1
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# 29-08-2013          0
# 31-08-2013          0
# 09-02-2013          0
# 09-04-2013          0
# 09-06-2013          0
# 09-08-2013          0
# 09-10-2013          0
# 09-12-2013          1
# 14-09-2013          1
# 16-09-2013          1
# 18-09-2013          1
# 20-09-2013          1
# 22-09-2013          1
# 24-09-2013          0
# 28-09-2013          0
# 10-06-2013          0
# 10-12-2013          0
# Spring              0
# Winter              1
# Summer              0
# Autumn              2
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0 = inp0[~inp0.Price.isnull()]

inp0 = inp0[~inp0.Season.isnull()]

inp0 = inp0[~inp0.NeckLine.isnull()]

inp0 = inp0[~inp0.SleeveLength.isnull()]

inp1 = inp1[~inp1.Winter.isnull()]

inp0 = inp0[~inp0.Autumn.isnull()]
inp0 = inp0[~inp0.Size.isnull()]

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               0
# Rating              0
# Size                0
# Season              0
# NeckLine            0
# SleeveLength        0
# Material          115
# FabricType        250
# Decoration        220
# Pattern Type       97
# Recommendation      0
# 29-08-2013          0
# 31-08-2013          0
# 09-02-2013          0
# 09-04-2013          0
# 09-06-2013          0
# 09-08-2013          0
# 09-10-2013          0
# 09-12-2013          0
# 14-09-2013          0
# 16-09-2013          0
# 18-09-2013          0
# 20-09-2013          0
# 22-09-2013          0
# 24-09-2013          0
# 28-09-2013          0
# 10-06-2013          0
# 10-12-2013          0
# Spring              0
# Winter              0
# Summer              0
# Autumn              0
# dtype: int64

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
#inp0["Season"].apply(lambda x:x if x=="Autumn" else "Autumn")

# %%
inp0["Season"].value_counts()
# Out:
# Summer    151
# Spring    115
# Winter     92
# Automn     59
# winter     44
# Autumn      7
# spring      2
# Name: Season, dtype: int64

# %%
inp0["Season"]=inp0["Season"].apply(lambda x:x if x!="Automn" else "Autumn")

# %%
inp0["Season"]=inp0["Season"].apply(lambda x:x if x!="winter" else "Winter")

# %%
inp0["Season"].value_counts()
# Out:
# Summer    151
# Winter    136
# Spring    115
# Autumn     66
# spring      2
# Name: Season, dtype: int64

# %%
inp0["SleeveLength"].value_counts()
# Out:
# sleevless         213
# short              92
# full               90
# halfsleeve         32
# threequarter       17
# thressqatar         8
# sleeveless          4
# capsleeves          3
# sleeevless          2
# cap-sleeves         2
# urndowncollor       1
# half                1
# turndowncollor      1
# threequater         1
# Petal               1
# butterfly           1
# sleveless           1
# Name: SleeveLength, dtype: int64

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="threequarter" else "threequater")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="thressqatar" else "threequater")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="capsleeves" else "cap-sleeves")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="sleeevless" else "sleeveless")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="sleveless" else "sleeveless")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="sleevless" else "sleeveless")

# %%
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="half" else "halfsleeve")
inp0["SleeveLength"]=inp0["SleeveLength"].apply(lambda x:x if x!="urndowncollor" else "turndowncollor")

# %%
inp0["SleeveLength"].value_counts()
# Out:
# sleeveless        220
# short              92
# full               90
# halfsleeve         33
# threequater        26
# cap-sleeves         5
# turndowncollor      2
# Petal               1
# butterfly           1
# Name: SleeveLength, dtype: int64

# %%
inp0.SleeveLength= inp0.SleeveLength.replace('cap-sleeves', "cap sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('full', "full sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('halfsleeve', "half sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace( 'sleeveless', "sleeve less")

inp0.SleeveLength= inp0.SleeveLength.replace('threequater', "three quater")

inp0.SleeveLength= inp0.SleeveLength.replace('turndowncollor', "turn down collar")

# %%
inp0["SleeveLength"].value_counts()
# Out:
# sleeve less         220
# short                92
# full sleeves         90
# half sleeves         33
# three quater         26
# cap sleeves           5
# turn down collar      2
# Petal                 1
# butterfly             1
# Name: SleeveLength, dtype: int64

# %%
inp0.Material= inp0.Material.replace(np.nan, "Missing")

inp0.FabricType= inp0.FabricType.replace(np.nan, "Missing")

inp0.Decoration= inp0.Decoration.replace(np.nan, "Missing")

inp0['Pattern Type']= inp0['Pattern Type'].replace(np.nan, "Missing")

# %%
inp0.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# 29-08-2013        0
# 31-08-2013        0
# 09-02-2013        0
# 09-04-2013        0
# 09-06-2013        0
# 09-08-2013        0
# 09-10-2013        0
# 09-12-2013        0
# 14-09-2013        0
# 16-09-2013        0
# 18-09-2013        0
# 20-09-2013        0
# 22-09-2013        0
# 24-09-2013        0
# 28-09-2013        0
# 10-06-2013        0
# 10-12-2013        0
# Spring            0
# Winter            0
# Summer            0
# Autumn            0
# dtype: int64

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 478
# Data columns (total 34 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        470 non-null    int64
#  1   Style           470 non-null    object
#  2   Price           470 non-null    object
#  3   Rating          470 non-null    float64
#  4   Size            470 non-null    object
#  5   Season          470 non-null    object
#  6   NeckLine        470 non-null    object
#  7   SleeveLength    470 non-null    object
#  8   Material        470 non-null    object
#  9   FabricType      470 non-null    object
#  10  Decoration      470 non-null    object
#  11  Pattern Type    470 non-null    object
#  12  Recommendation  470 non-null    int64
#  13  29-08-2013      470 non-null    int64
#  14  31-08-2013      470 non-null    int64
#  15  09-02-2013      470 non-null    int64
#  16  09-04-2013      470 non-null    int64
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  ... 20-09-2013 22-09-2013  \
# 0   sleeve less        Missing    chiffon  ...     3386.0     3479.0
# 1         Petal     microfiber    Missing  ...     2106.0     2454.0
# 2  full sleeves       polyster    Missing  ...       10.0       11.0
# 3  full sleeves           silk    chiffon  ...     1812.0     1845.0
# 4     butterfly  chiffonfabric    chiffon  ...     1824.0     1919.0
#
#    24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Winter  Summer  \
# 0        3554        3706        3897        4048    2660  9658.0   13899
# ...

# %%
all_season=inp0.groupby("Style")["Winter","Spring","Autumn","Summer"].sum()
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\906006611.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season=inp0.groupby("Style")["Winter","Spring","Autumn","Summer"].sum()

# %%
all_season
# Out:
#             Winter  Spring    Autumn  Summer
# Style
# Brief      25020.0    7484   69821.0   37303
# Casual    192915.0   60978  566717.0  282907
# Flare        406.0      71    1161.0     451
# Novelty     2504.0     563    7353.0    2866
# OL            53.0      15     158.0      63
# Sexy       81263.0   23451  230524.0  117117
# bohemian   11752.0    3800   37446.0   16119
# cute       63999.0   20022  179466.0   98512
# fashion       74.0      19     211.0      91
# party      24558.0    7987   73978.0   35518
# sexy       15173.0    3564   39002.0   19704
# vintage    33595.0    8693   91439.0   46847
# work       16882.0    4893   46389.0   24931

# %%
all_season["total"]=all_season["Winter"]+all_season["Spring"]+all_season['Autumn']+all_season['Summer']

# %%
all_season[all_season['total']<50000]
# Out:
#          Winter  Spring  Autumn  Summer    total
# Style
# Flare     406.0      71  1161.0     451   2089.0
# Novelty  2504.0     563  7353.0    2866  13286.0
# OL         53.0      15   158.0      63    289.0
# fashion    74.0      19   211.0      91    395.0

# %%
inp0["Style"]=inp0.Style.replace( ['Flare','Novelty','fashion','OL'], "Others")

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  ... 20-09-2013 22-09-2013  \
# 0   sleeve less        Missing    chiffon  ...     3386.0     3479.0
# 1         Petal     microfiber    Missing  ...     2106.0     2454.0
# 2  full sleeves       polyster    Missing  ...       10.0       11.0
# 3  full sleeves           silk    chiffon  ...     1812.0     1845.0
# 4     butterfly  chiffonfabric    chiffon  ...     1824.0     1919.0
#
#    24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Winter  Summer  \
# 0        3554        3706        3897        4048    2660  9658.0   13899
# ...

# %%
inp0['Style'].value_counts(normalize=True)
# Out:
# Casual      0.459574
# Sexy        0.138298
# party       0.102128
# cute        0.091489
# vintage     0.053191
# bohemian    0.048936
# Brief       0.036170
# work        0.036170
# Others      0.021277
# sexy        0.012766
# Name: Style, dtype: float64

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
(inp0["Style"].value_counts(normalize=True)*100)
# Out:
# Casual      45.957447
# Sexy        13.829787
# party       10.212766
# cute         9.148936
# vintage      5.319149
# bohemian     4.893617
# Brief        3.617021
# work         3.617021
# Others       2.127660
# sexy         1.276596
# Name: Style, dtype: float64

# %%
(inp0["Style"].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
all_season_1=inp0.groupby("NeckLine")["Winter","Spring","Autumn","Summer"].sum()
all_season_1
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3979857209.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_1=inp0.groupby("NeckLine")["Winter","Spring","Autumn","Summer"].sum()
#                    Winter  Spring    Autumn  Summer
# NeckLine
# Scoop               478.0     198    1802.0     657
# Sweetheart         2264.0     911    8341.0    3072
# backless            408.0     190    1690.0     600
# boat-neck          9265.0    2784   27968.0   13032
# bowneck            3354.0    1325   12371.0    4583
# halter              363.0     151    1336.0     505
# mandarin-collor      53.0      15     158.0      63
# o-neck           299164.0   87920  852013.0  431964
# open               1330.0     405    3621.0    2040
# peterpan-collor    3307.0    1141    9031.0    5429
# ruffled           20388.0    7374   55532.0   35577
# slash-neck        11547.0    3866   36571.0   16412
# ...

# %%
all_season_1["total"]=all_season_1["Winter"]+all_season_1["Spring"]+all_season_1['Autumn']+all_season_1['Summer']
all_season_1
# Out:
#                    Winter  Spring    Autumn  Summer      total
# NeckLine
# Scoop               478.0     198    1802.0     657     3135.0
# Sweetheart         2264.0     911    8341.0    3072    14588.0
# backless            408.0     190    1690.0     600     2888.0
# boat-neck          9265.0    2784   27968.0   13032    53049.0
# bowneck            3354.0    1325   12371.0    4583    21633.0
# halter              363.0     151    1336.0     505     2355.0
# mandarin-collor      53.0      15     158.0      63      289.0
# o-neck           299164.0   87920  852013.0  431964  1671061.0
# open               1330.0     405    3621.0    2040     7396.0
# peterpan-collor    3307.0    1141    9031.0    5429    18908.0
# ruffled           20388.0    7374   55532.0   35577   118871.0
# slash-neck        11547.0    3866   36571.0   16412    68396.0
# sqare-collor       5683.0    1750   16503.0    8459    32395.0
# sweetheart          409.0     181    1557.0     581     2728.0
# ...

# %%
all_season_1[all_season_1['total']<50000]
# Out:
#                  Winter  Spring   Autumn  Summer    total
# NeckLine
# Scoop             478.0     198   1802.0     657   3135.0
# Sweetheart       2264.0     911   8341.0    3072  14588.0
# backless          408.0     190   1690.0     600   2888.0
# bowneck          3354.0    1325  12371.0    4583  21633.0
# halter            363.0     151   1336.0     505   2355.0
# mandarin-collor    53.0      15    158.0      63    289.0
# open             1330.0     405   3621.0    2040   7396.0
# peterpan-collor  3307.0    1141   9031.0    5429  18908.0
# sqare-collor     5683.0    1750  16503.0    8459  32395.0
# sweetheart        409.0     181   1557.0     581   2728.0

# %%
inp0["NeckLine"]=inp0["NeckLine"].replace(['Scoop', 'Sweetheart', 'backless', 'bowneck', 'halter',
       'mandarin-collor', 'open', 'peterpan-collor', 'sqare-collor',
       'sweetheart'],"Others")

# %%
inp0["NeckLine"].value_counts()
# Out:
# o-neck            254
# v-neck            117
# Others             42
# slash-neck         25
# boat-neck          18
# turndowncollor     13
# ruffled             1
# Name: NeckLine, dtype: int64

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
all_season_2=inp0.groupby("SleeveLength")["Winter","Spring","Autumn","Summer"].sum()
all_season_2
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\1203984703.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_2=inp0.groupby("SleeveLength")["Winter","Spring","Autumn","Summer"].sum()
#                     Winter  Spring    Autumn  Summer
# SleeveLength
# Petal               6405.0     750   17311.0    6216
# butterfly           5678.0    1396   14676.0    7706
# cap sleeves         1974.0     924    7813.0    2892
# full sleeves       80307.0   25035  233323.0  116788
# half sleeves       35812.0   11843  105055.0   55133
# short             124509.0   37439  347819.0  186363
# sleeve less       171075.0   50927  501247.0  242286
# three quater       41802.0   13066  114363.0   64312
# turn down collar     632.0     160    2058.0     733

# %%
all_season_2["total"]=all_season_2["Winter"]+all_season_2["Spring"]+all_season_2['Autumn']+all_season_2['Summer']
all_season_2
# Out:
#                     Winter  Spring    Autumn  Summer     total
# SleeveLength
# Petal               6405.0     750   17311.0    6216   30682.0
# butterfly           5678.0    1396   14676.0    7706   29456.0
# cap sleeves         1974.0     924    7813.0    2892   13603.0
# full sleeves       80307.0   25035  233323.0  116788  455453.0
# half sleeves       35812.0   11843  105055.0   55133  207843.0
# short             124509.0   37439  347819.0  186363  696130.0
# sleeve less       171075.0   50927  501247.0  242286  965535.0
# three quater       41802.0   13066  114363.0   64312  233543.0
# turn down collar     632.0     160    2058.0     733    3583.0

# %%
all_season_2[all_season_2['total']<50000]
# Out:
#                   Winter  Spring   Autumn  Summer    total
# SleeveLength
# Petal             6405.0     750  17311.0    6216  30682.0
# butterfly         5678.0    1396  14676.0    7706  29456.0
# cap sleeves       1974.0     924   7813.0    2892  13603.0
# turn down collar   632.0     160   2058.0     733   3583.0

# %%
inp0["SleeveLength"]=inp0.SleeveLength.replace( ['Petal','butterfly','cap sleeves','turn down collar'], "Others")
inp0["SleeveLength"].value_counts()
# Out:
# sleeve less     220
# short            92
# full sleeves     90
# half sleeves     33
# three quater     26
# Others            9
# Name: SleeveLength, dtype: int64

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
all_season_1=inp0.groupby("Material")["Winter","Spring","Autumn","Summer"].sum()
all_season_1
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\277334117.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_1=inp0.groupby("Material")["Winter","Spring","Autumn","Summer"].sum()
#                  Winter  Spring    Autumn  Summer
# Material
# Missing        118645.0   35005  336752.0  172769
# acrylic          1956.0     749    6628.0    2822
# cashmere          985.0     312    2920.0    1450
# chiffonfabric   57014.0   20019  163959.0   92292
# cotton         129821.0   38460  372874.0  186262
# lace             1127.0     350    3046.0    1773
# linen            3723.0    1061   10008.0    5357
# lycra            2389.0     559    6383.0    3224
# microfiber       6571.0     825   17967.0    6454
# milksilk         6024.0    1807   17107.0    8772
# mix             12723.0    3266   34817.0   17684
# modal              95.0      31     249.0     147
# ...

# %%
all_season_1["total"]=all_season_1["Winter"]+all_season_1["Spring"]+all_season_1['Autumn']+all_season_1['Summer']
all_season_1
# Out:
#                  Winter  Spring    Autumn  Summer     total
# Material
# Missing        118645.0   35005  336752.0  172769  663171.0
# acrylic          1956.0     749    6628.0    2822   12155.0
# cashmere          985.0     312    2920.0    1450    5667.0
# chiffonfabric   57014.0   20019  163959.0   92292  333284.0
# cotton         129821.0   38460  372874.0  186262  727417.0
# lace             1127.0     350    3046.0    1773    6296.0
# linen            3723.0    1061   10008.0    5357   20149.0
# lycra            2389.0     559    6383.0    3224   12555.0
# microfiber       6571.0     825   17967.0    6454   31817.0
# milksilk         6024.0    1807   17107.0    8772   33710.0
# mix             12723.0    3266   34817.0   17684   68490.0
# modal              95.0      31     249.0     147     522.0
# model              43.0       8     144.0      50     245.0
# nylon            4781.0    1705   16421.0    6576   29483.0
# ...

# %%
all_season_1[all_season_1['total']<25000]
# Out:
#           Winter  Spring   Autumn  Summer    total
# Material
# acrylic   1956.0     749   6628.0    2822  12155.0
# cashmere   985.0     312   2920.0    1450   5667.0
# lace      1127.0     350   3046.0    1773   6296.0
# linen     3723.0    1061  10008.0    5357  20149.0
# lycra     2389.0     559   6383.0    3224  12555.0
# modal       95.0      31    249.0     147    522.0
# model       43.0       8    144.0      50    245.0
# other      901.0     307   3097.0    1153   5458.0
# shiffon   1353.0     490   4575.0    1877   8295.0
# sill       662.0      11   1514.0     532   2719.0
# spandex   3924.0    1215  11333.0    5930  22402.0
# viscos     576.0     300   2407.0     897   4180.0
# wool       150.0      28    522.0     159    859.0

# %%
inp0["Material"]=inp0.Material.replace( ['acrylic', 'cashmere', 'lace', 'linen', 'lycra', 'modal', 'model',
       'other', 'shiffon', 'sill', 'spandex', 'viscos', 'wool'], "Others")
inp0["Material"].value_counts()
# Out:
# cotton           144
# Missing          115
# polyster          92
# Others            29
# silk              26
# chiffonfabric     24
# mix               12
# nylon             10
# rayon             10
# milksilk           5
# microfiber         3
# Name: Material, dtype: int64

# %%
inp0.iloc[:1,9:]
# Out:
#   FabricType Decoration Pattern Type  Recommendation  29-08-2013  31-08-2013  \
# 0    chiffon    ruffles       animal               1        2114        2274
#
#    09-02-2013  09-04-2013  09-06-2013  09-08-2013  ...  20-09-2013  \
# 0        2491        2660        2727        2887  ...      3386.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Winter  \
# 0      3479.0        3554        3706        3897        4048    2660  9658.0
#
#    Summer   Autumn
# 0   13899  26857.0
#
# [1 rows x 25 columns]

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.

all_season_1=inp0.groupby("FabricType")["Winter","Spring","Autumn","Summer"].sum()
all_season_1.head()
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\1825314561.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_1=inp0.groupby("FabricType")["Winter","Spring","Autumn","Summer"].sum()
#               Winter  Spring    Autumn  Summer
# FabricType
# Corduroy      1640.0     688    6259.0    2279
# Missing     216901.0   64656  626217.0  310173
# batik          854.0      98    2205.0     864
# broadcloth   21585.0    6149   61546.0   30718
# chiffon     176256.0   54882  502920.0  265061

# %%
all_season_1["total"]=all_season_1["Winter"]+all_season_1["Spring"]+all_season_1['Autumn']+all_season_1['Summer']
all_season_1.head()
# Out:
#               Winter  Spring    Autumn  Summer      total
# FabricType
# Corduroy      1640.0     688    6259.0    2279    10866.0
# Missing     216901.0   64656  626217.0  310173  1217947.0
# batik          854.0      98    2205.0     864     4021.0
# broadcloth   21585.0    6149   61546.0   30718   119998.0
# chiffon     176256.0   54882  502920.0  265061   999119.0

# %%
all_season_1[all_season_1['total']<25000]
# Out:
#             Winter  Spring  Autumn  Summer    total
# FabricType
# Corduroy    1640.0     688  6259.0    2279  10866.0
# batik        854.0      98  2205.0     864   4021.0
# dobby        497.0     146  1374.0     744   2761.0
# flannael    1301.0     321  3462.0    1751   6835.0
# flannel     2595.0     854  6995.0    4289  14733.0
# knitted        2.0       1     8.0       3     14.0
# knitting       7.0       2    21.0       9     39.0
# lace         309.0     141  1186.0     446   2082.0
# organza      109.0      51   442.0     160    762.0
# other        284.0      25   678.0     264   1251.0
# poplin       239.0      84   787.0     333   1443.0
# satin       2807.0     341  5879.0    2376  11403.0
# sattin      1651.0     456  5580.0    1986   9673.0
# terry         60.0      25   208.0      80    373.0
# tulle        313.0     136  1231.0     439   2119.0
# wollen       416.0     184  1658.0     600   2858.0

# %%
['Corduroy','batik','dobby','flannael','flannel','knitted','knitting','lace','organza','other','poplin','satin','sattin','terry','tulle','wollen']
# Out:
# ['Corduroy',
#  'batik',
#  'dobby',
#  'flannael',
#  'flannel',
#  'knitted',
#  'knitting',
#  'lace',
#  'organza',
#  'other',
#  'poplin',
#  'satin',
#  'sattin',
#  'terry',
#  'tulle',
#  'wollen']

# %%
inp0["FabricType"]=inp0.Material.replace( ['Corduroy','batik','dobby','flannael','flannel','knitted','knitting','lace','organza','other','poplin','satin','sattin','terry','tulle','wollen'], "Others")
inp0["FabricType"].value_counts()
# Out:
# cotton           144
# Missing          115
# polyster          92
# Others            29
# silk              26
# chiffonfabric     24
# mix               12
# nylon             10
# rayon             10
# milksilk           5
# microfiber         3
# Name: FabricType, dtype: int64

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
all_season_1=inp0.groupby("Pattern Type")["Winter","Spring","Autumn","Summer"].sum()
all_season_1
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\803616072.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_1=inp0.groupby("Pattern Type")["Winter","Spring","Autumn","Summer"].sum()
#                 Winter  Spring    Autumn  Summer
# Pattern Type
# Missing        40712.0   14507  133766.0   58656
# animal         39725.0    9969  107604.0   53975
# character        728.0     176    1841.0     993
# dot            43181.0   14173  117370.0   70367
# floral          1933.0     534    5340.0    2807
# geometric      20620.0    6584   54131.0   33000
# leapord          538.0     124    1732.0     623
# leopard         5022.0    1164   12169.0    6912
# none             951.0     389    3360.0    1291
# patchwork      33501.0   10224   98233.0   48402
# plaid            256.0      64     703.0     346
# print          72677.0   20917  204370.0  105061
# ...

# %%
all_season_1["total"]=all_season_1["Winter"]+all_season_1["Spring"]+all_season_1['Autumn']+all_season_1['Summer']
all_season_1.head()
# Out:
#                Winter  Spring    Autumn  Summer     total
# Pattern Type
# Missing       40712.0   14507  133766.0   58656  247641.0
# animal        39725.0    9969  107604.0   53975  211273.0
# character       728.0     176    1841.0     993    3738.0
# dot           43181.0   14173  117370.0   70367  245091.0
# floral         1933.0     534    5340.0    2807   10614.0

# %%
all_season_1[all_season_1['total']<25000]
# Out:
#               Winter  Spring  Autumn  Summer    total
# Pattern Type
# character      728.0     176  1841.0     993   3738.0
# floral        1933.0     534  5340.0    2807  10614.0
# leapord        538.0     124  1732.0     623   3017.0
# none           951.0     389  3360.0    1291   5991.0
# plaid          256.0      64   703.0     346   1369.0
# splice         810.0     270  2990.0    1042   5112.0

# %%
inp0["Pattern Type"]=inp0.Material.replace( ['character','floral','leapord','none','plaid','splice'], "Others")
inp0["Pattern Type"].value_counts()
# Out:
# cotton           144
# Missing          115
# polyster          92
# Others            29
# silk              26
# chiffonfabric     24
# mix               12
# nylon             10
# rayon             10
# milksilk           5
# microfiber         3
# Name: Pattern Type, dtype: int64

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
all_season_1=inp0.groupby("Decoration")["Winter","Spring","Autumn","Summer"].sum()
all_season_1
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\1043445467.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_season_1=inp0.groupby("Decoration")["Winter","Spring","Autumn","Summer"].sum()
#               Winter  Spring    Autumn  Summer
# Decoration
# Missing     191284.0   58641  557288.0  277261
# Tiered        3910.0    1268   10603.0    6366
# applique     12441.0    3355   34835.0   17201
# beading       8839.0    2425   25910.0   11737
# bow          44467.0   15114  122906.0   72872
# button        4200.0     998   11615.0    5390
# cascading       34.0       8     126.0      42
# crystal        940.0     420    3744.0    1346
# draped        1054.0     550    3923.0    1572
# embroidary    7803.0    1888   21692.0   10485
# feathers        12.0       3      35.0      14
# flowers       1046.0     426    3702.0    1502
# hollowout    12287.0    3267   35807.0   16397
# ...

# %%
all_season_1["total"]=all_season_1["Winter"]+all_season_1["Spring"]+all_season_1['Autumn']+all_season_1['Summer']
all_season_1.head()
# Out:
#               Winter  Spring    Autumn  Summer      total
# Decoration
# Missing     191284.0   58641  557288.0  277261  1084474.0
# Tiered        3910.0    1268   10603.0    6366    22147.0
# applique     12441.0    3355   34835.0   17201    67832.0
# beading       8839.0    2425   25910.0   11737    48911.0
# bow          44467.0   15114  122906.0   72872   255359.0

# %%
all_season_1[all_season_1['total']<25000]
# Out:
#             Winter  Spring   Autumn  Summer    total
# Decoration
# Tiered      3910.0    1268  10603.0    6366  22147.0
# button      4200.0     998  11615.0    5390  22203.0
# cascading     34.0       8    126.0      42    210.0
# crystal      940.0     420   3744.0    1346   6450.0
# draped      1054.0     550   3923.0    1572   7099.0
# feathers      12.0       3     35.0      14     64.0
# flowers     1046.0     426   3702.0    1502   6676.0
# none         538.0     217   2059.0     737   3551.0
# pearls         7.0       2     24.0       8     41.0
# plain        399.0     168   1600.0     573   2740.0
# pockets     3891.0    1149  10887.0    5605  21532.0
# rivet       2605.0    1225  10066.0    3905  17801.0
# ruched      1164.0     526   4574.0    1676   7940.0
# tassel       154.0      42    562.0     181    939.0

# %%
inp0["Decoration"]=inp0.Material.replace( ['Tiered', 'button', 'cascading', 'crystal', 'draped', 'feathers',
       'flowers', 'none', 'pearls', 'plain', 'pockets', 'rivet', 'ruched',
       'tassel'], "Others")
inp0["Decoration"].value_counts()
# Out:
# cotton           144
# Missing          115
# polyster          92
# Others            29
# silk              26
# chiffonfabric     24
# mix               12
# nylon             10
# rayon             10
# milksilk           5
# microfiber         3
# Name: Decoration, dtype: int64

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %%
-ans is style
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 -ans is style
#
# NameError: name 'ans' is not defined

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
ans is 52000
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3996755653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ans is 52000
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3996755653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ans is 52000
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3996755653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ans is 52000
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3996755653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ans is 52000
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\3996755653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ans is 52000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...

# %%
# Describe the numerical variale: "Autumn".
inp0["Autumn"].describe()
# Out:
# count      470.000000
# mean      2858.861702
# std       5040.707948
# min          1.000000
# 25%        416.500000
# 50%       1335.000000
# 75%       3128.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
# plot the boxplot of "Autumn" column.
plt.figure(figsize=(5,6))
sns.boxplot(inp0["Autumn"])
plt.show()

# %%
inp0["Summer"].describe()
# Out:
# count      470.000000
# mean      1451.976596
# std       2998.391276
# min          2.000000
# 25%        157.250000
# 50%        519.000000
# 75%       1476.750000
# max      35577.000000
# Name: Summer, dtype: float64

# %%
inp0["Winter"].describe()
# Out:
# count      470.000000
# mean       996.157447
# std       1863.250377
# min          0.000000
# 25%        123.250000
# 50%        404.000000
# 75%       1097.000000
# max      20388.000000
# Name: Winter, dtype: float64

# %%
inp0["Spring"].describe()
# Out:
# count     470.000000
# mean      301.148936
# std       605.957118
# min         1.000000
# 25%        29.000000
# 50%       112.000000
# 75%       308.750000
# max      7374.000000
# Name: Spring, dtype: float64

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
ans is Autumn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 ans is Autumn
#
# NameError: name 'ans' is not defined

# %%
# Find the maximum and 99th percentile of Winter season.
inp0["Winter"].quantile([0.99])
# Out:
# 0.99    8994.91
# Name: Winter, dtype: float64

# %%
# Find the maximum and 99th percentile of Summer season.
inp0["Summer"].quantile([0.99])
# Out:
# 0.99    13976.5
# Name: Summer, dtype: float64

# %%
# Find the maximum and 99th percentile of Spring season.
inp0["Spring"].quantile([0.99])
# Out:
# 0.99    2657.24
# Name: Spring, dtype: float64

# %%
# Find the maximum and 99th percentile of Autumn season.
inp0["Autumn"].quantile([0.99])
# Out:
# 0.99    24155.7
# Name: Autumn, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material     FabricType  ... 20-09-2013 22-09-2013  \
# 0   sleeve less        Missing        Missing  ...     3386.0     3479.0
# 1        Others     microfiber     microfiber  ...     2106.0     2454.0
# 2  full sleeves       polyster       polyster  ...       10.0       11.0
# 3  full sleeves           silk           silk  ...     1812.0     1845.0
# 4        Others  chiffonfabric  chiffonfabric  ...     1824.0     1919.0
#
#    24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Winter  Summer  \
# ...

# %%
# Find the Mean of Ratings for each Price category.
group_data=inp0.groupby("Price")

# %%
means=group_data["Rating"].mean()
means
# Out:
# Price
# Average      3.454430
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.280000
# Name: Rating, dtype: float64

# %% [markdown]
# ans is high

# %%
# Find the median of Ratings for each Style category.
group_data=inp0.groupby("Style")

# %%
medians=group_data["Rating"].median()
medians
# Out:
# Style
# Brief       4.60
# Casual      4.60
# Others      0.00
# Sexy        4.60
# bohemian    4.60
# cute        4.60
# party       4.70
# sexy        4.55
# vintage     4.60
# work        4.70
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %% [markdown]
# ans is 4.6

# %%
inp0["Style"].value_counts().describe()
# Out:
# count     10.000000
# mean      47.000000
# std       62.193247
# min        6.000000
# 25%       17.000000
# 50%       24.000000
# 75%       46.750000
# max      216.000000
# Name: Style, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %% [markdown]
# ans is Autumn

# %%
inp0.groupby("Recommendation")["Summer","Winter","Spring","Autumn"].mean().plot.bar()
# Out:
# C:\Users\ramee\AppData\Local\Temp\ipykernel_15504\2712179259.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   inp0.groupby("Recommendation")["Summer","Winter","Spring","Autumn"].mean().plot.bar()
# <Axes: xlabel='Recommendation'>

# %%
# Summer sale vs Recommendation.
inp0.groupby("Recommendation")["Summer"].mean().plot.bar()
# Out:
# <Axes: xlabel='Recommendation'>

# %%
# Spring sale vs Recommendation.
inp0.groupby("Recommendation")["Spring"].mean().plot.bar()
# Out:
# <Axes: xlabel='Recommendation'>

# %%
# Autumn sale vs Recommendation.
inp0.groupby("Recommendation")["Autumn"].mean().plot.bar()
# Out:
# <Axes: xlabel='Recommendation'>

# %%
# Winter sale vs Recommendation.
inp0.groupby("Recommendation")["Winter"].mean().plot.bar()
# Out:
# <Axes: xlabel='Recommendation'>

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %% [markdown]
# ans is medium and free

# %%
# Size vs Recommendation.
inp0.groupby("Size")["Recommendation"].sum().plot.bar()
# Out:
# <Axes: xlabel='Size'>

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %% [markdown]
# ans is Price: medium and style: cute

# %%
df=pd.pivot_table(inp0, index="Style", columns="Price",values="Recommendation")
df
# Out:
# Price      Average      High       Low    Medium  very-high
# Style
# Brief     0.333333       NaN  0.000000       NaN        NaN
# Casual    0.345455  0.666667  0.379310  0.666667   1.000000
# Others    0.375000       NaN       NaN  0.500000        NaN
# Sexy      0.344828  0.000000  0.500000  0.000000   0.000000
# bohemian  0.333333       NaN  0.666667  1.000000   1.000000
# cute      0.400000  0.666667  0.500000  1.000000        NaN
# party     0.647059  0.333333       NaN  0.800000   0.823529
# sexy      0.000000       NaN  0.750000  0.000000        NaN
# vintage   0.352941  0.000000  0.250000  0.500000        NaN
# work      0.214286       NaN  0.000000  0.000000        NaN

# %%
# plot the heat map of Style, price and Recommendation.
sns.heatmap(df,annot=True)
# Out:
# <Axes: xlabel='Price', ylabel='Style'>

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %% [markdown]
# ans is milksilk and microfiber

# %%
df_1=pd.pivot_table(inp0,index="Season", columns="Material",values="Recommendation")
df_1
# Out:
# Material   Missing    Others  chiffonfabric    cotton  microfiber  milksilk  \
# Season
# Autumn    0.428571  0.000000          0.500  0.294118         NaN       1.0
# Spring    0.696970  0.500000          0.600  0.560000         1.0       NaN
# Summer    0.454545  0.142857          0.125  0.383562         0.0       0.0
# Winter    0.481481  0.400000          0.000  0.500000         0.0       0.0
# spring    0.000000       NaN            NaN  1.000000         NaN       NaN
#
# Material       mix     nylon  polyster     rayon      silk
# Season
# Autumn         NaN  0.000000  0.266667  0.666667  0.000000
# Spring    0.500000  0.333333  0.571429  1.000000  0.538462
# Summer    0.333333  1.000000  0.071429  0.333333  0.000000
# Winter    0.200000  0.333333  0.346939       NaN  0.714286
# spring         NaN       NaN       NaN       NaN       NaN

# %%
# plot the heat map of Season, material and Recommendation.
sns.heatmap(df_1,annot=True)
# Out:
# <Axes: xlabel='Material', ylabel='Season'>
